# %% [markdown]
# <a href="https://colab.research.google.com/github/Sahil-sethu/saahil/blob/main/learning_python_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
2+2
# Out:
# 4

# %%
2 > 1
# Out:
# True

# %%
2>5
# Out:
# False

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("*" * 10)
# Out:
# **********
